# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL/blob/master/FinRL_StockTrading_NeurIPS_2018.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading
#
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)
# * [RLlib Section](#7)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
## install finrl library
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL-Library.git
# Out:
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL-Library.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL-Library.git to /private/var/folders/6h/lpcm_n7d1hg47zhs852wxbt40000gn/T/pip-req-build-38817uwr
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL-Library.git /private/var/folders/6h/lpcm_n7d1hg47zhs852wxbt40000gn/T/pip-req-build-38817uwr

# %%
from finrl import config
from finrl import config_tickers
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.finrl_meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.finrl_meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.finrl_meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.finrl_meta.data_processor import DataProcessor

from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools
# Out:
# /Users/yudongtan/miniforge3/lib/python3.9/site-packages/pandas_datareader/compat/__init__.py:11: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   PANDAS_VERSION = LooseVersion(pd.__version__)
# /Users/yudongtan/miniforge3/lib/python3.9/site-packages/pyfolio/pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(
# /Users/yudongtan/miniforge3/lib/python3.9/site-packages/seaborn/rcmod.py:82: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) >= "3.0":
# /Users/yudongtan/miniforge3/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
# from config.py TRAIN_START_DATE is a string
config.TRAIN_START_DATE
# Out:
# '2014-01-01'

# %%
# from config.py TRAIN_END_DATE is a string
config.TRAIN_END_DATE
# Out:
# '2020-07-31'

# %%
df = YahooDownloader(start_date = '2009-01-01',
                     end_date = '2021-10-31',
                     ticker_list = config_tickers.DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# Shape of DataFrame:  (94360, 8)

# %%
print(config_tickers.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
df.shape
# Out:
# (94360, 8)

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2008-12-31   3.070357   3.133571   3.047857   2.606278  607541200  AAPL
# 1  2008-12-31  57.110001  58.220001  57.060001  43.924454    6287200  AMGN
# 2  2008-12-31  17.969999  18.750000  17.910000  14.908462    9625600   AXP
# 3  2008-12-31  41.590000  43.049999  41.500000  32.005882    5443100    BA
# 4  2008-12-31  43.700001  45.099998  43.700001  30.628832    6277400   CAT
#
#    day
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = config.INDICATORS,
                    use_vix=True,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
# Out:
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/preprocessors.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (3231, 8)
# Successfully added vix
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# Successfully added turbulence index

# %%
list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed_full.fillna(0)

# %%
processed_full.sort_values(['date','tic'],ignore_index=True).head(10)
# Out:
#          date   tic       open       high        low      close       volume  \
# 0  2008-12-31  AAPL   3.070357   3.133571   3.047857   2.606278  607541200.0
# 1  2008-12-31  AMGN  57.110001  58.220001  57.060001  43.924454    6287200.0
# 2  2008-12-31   AXP  17.969999  18.750000  17.910000  14.908462    9625600.0
# 3  2008-12-31    BA  41.590000  43.049999  41.500000  32.005882    5443100.0
# 4  2008-12-31   CAT  43.700001  45.099998  43.700001  30.628832    6277400.0
# 5  2008-12-31   CRM   7.712500   8.130000   7.707500   8.002500    5367600.0
# 6  2008-12-31  CSCO  16.180000  16.549999  16.120001  11.787784   37513700.0
# 7  2008-12-31   CVX  72.900002  74.629997  72.900002  43.314423    9964300.0
# 8  2008-12-31   DIS  22.570000  22.950001  22.520000  19.538345    9012100.0
# 9  2008-12-31    GS  82.239998  86.150002  81.120003  68.802803   14894100.0
#
#    day  macd   boll_ub   boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0  2.0   0.0  2.921923  2.455528   100.0  66.666667  100.0      2.606278
# 1  2.0   0.0  2.921923  2.455528   100.0  66.666667  100.0     43.924454
# 2  2.0   0.0  2.921923  2.455528   100.0  66.666667  100.0     14.908462
# 3  2.0   0.0  2.921923  2.455528   100.0  66.666667  100.0     32.005882
# 4  2.0   0.0  2.921923  2.455528   100.0  66.666667  100.0     30.628832
# 5  2.0   0.0  2.921923  2.455528   100.0  66.666667  100.0      8.002500
# 6  2.0   0.0  2.921923  2.455528   100.0  66.666667  100.0     11.787784
# 7  2.0   0.0  2.921923  2.455528   100.0  66.666667  100.0     43.314423
# 8  2.0   0.0  2.921923  2.455528   100.0  66.666667  100.0     19.538345
# 9  2.0   0.0  2.921923  2.455528   100.0  66.666667  100.0     68.802803
#
#    close_60_sma   vix  turbulence
# 0      2.606278  40.0         0.0
# 1     43.924454  40.0         0.0
# 2     14.908462  40.0         0.0
# 3     32.005882  40.0         0.0
# 4     30.628832  40.0         0.0
# 5      8.002500  40.0         0.0
# 6     11.787784  40.0         0.0
# 7     43.314423  40.0         0.0
# 8     19.538345  40.0         0.0
# 9     68.802803  40.0         0.0

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %% [markdown]
# ## Training data split: 2009-01-01 to 2020-07-01
# ## Trade data split: 2020-07-01 to 2021-10-31

# %%
train = data_split(processed_full, '2009-01-01','2020-07-01')
trade = data_split(processed_full, '2020-07-01','2021-10-31')
print(len(train))
print(len(trade))
# Out:
# 83897
# 9744

# %%
train.tail()
# Out:
#             date  tic        open        high         low       close  \
# 2892  2020-06-30  UNH  288.570007  296.450012  287.660004  287.776794
# 2892  2020-06-30    V  191.490005  193.750000  190.160004  190.737244
# 2892  2020-06-30   VZ   54.919998   55.290001   54.360001   50.376740
# 2892  2020-06-30  WBA   42.119999   42.580002   41.759998   39.035728
# 2892  2020-06-30  WMT  119.220001  120.129997  118.540001  116.121773
#
#           volume  day      macd     boll_ub     boll_lb     rsi_30     cci_30  \
# 2892   2932900.0  1.0 -0.019478  303.925893  271.251238  52.413044 -25.838425
# 2892   9040100.0  1.0  1.048786  198.750529  185.041397  53.021036 -51.550794
# 2892  17414800.0  1.0 -0.437111   53.918427   48.729322  48.097034 -51.018326
# 2892   4782100.0  1.0 -0.083987   42.609306   36.487093  48.830175 -14.508170
# 2892   6836400.0  1.0 -0.886569  119.473757  113.510459  48.159674 -69.938739
#
#          dx_30  close_30_sma  close_60_sma    vix  turbulence
# 2892  1.846804    288.020687    281.001443  30.43   12.918791
# 2892  2.013358    191.485038    181.677684  30.43   12.918791
# 2892  8.508886     51.012122     51.464679  30.43   12.918791
# 2892  1.500723     39.135189     38.935129  30.43   12.918791
# 2892  3.847271    117.787628    119.723275  30.43   12.918791

# %%
trade.head()
# Out:
#          date   tic        open        high         low       close  \
# 0  2020-07-01  AAPL   91.279999   91.839996   90.977501   89.904594
# 0  2020-07-01  AMGN  235.520004  256.230011  232.580002  240.153946
# 0  2020-07-01   AXP   95.250000   96.959999   93.639999   92.086380
# 0  2020-07-01    BA  185.880005  190.610001  180.039993  180.320007
# 0  2020-07-01   CAT  129.380005  129.399994  125.879997  120.651634
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  110737200.0  2.0  3.014603   92.699319   80.179953  62.807126  107.491819
# 0    6575800.0  2.0  3.636393  232.397421  200.212949  61.279630  271.386075
# 0    3301000.0  2.0 -0.389162  110.423945   87.759332  48.504818  -66.328697
# 0   49036700.0  2.0  5.443193  220.721139  160.932863  50.925771   24.220608
# 0    2807800.0  2.0  1.272630  130.624272  113.353134  52.865421   35.597292
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  29.730532     83.933767     77.717544  28.620001   53.068143
# 0  46.806139    214.858661    215.931664  28.620001   53.068143
# 0   3.142448     97.244636     90.695525  28.620001   53.068143
# 0  15.932920    176.472335    155.614168  28.620001   53.068143
# 0  14.457404    119.412837    113.646674  28.620001   53.068143

# %%
config.INDICATORS
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(config.INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": config.INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %% [markdown]
# ## Environment for Training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
agent = DRLAgent(env = env_train)

# %% [markdown]
# ### Model Training: 5 models, A2C DDPG, PPO, TD3, SAC

# %% [markdown]
# ### Model 1: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cpu device

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                             tb_log_name='a2c',
                             total_timesteps=50000)
# Out:
# -------------------------------------
# | time/                 |           |
# |    fps                | 244       |
# |    iterations         | 100       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.274    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -21.4     |
# |    reward             | 0.2950889 |
# |    std                | 1         |
# |    value_loss         | 0.634     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 245       |
# |    iterations         | 200       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.0277   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -1.54     |
# |    reward             | -2.016495 |
# |    std                | 1.01      |
# |    value_loss         | 0.218     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 246       |
# |    iterations         | 300       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -186      |
# |    reward             | 5.1184154 |
# |    std                | 1         |
# |    value_loss         | 20.6      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 247        |
# |    iterations         | 400        |
# |    time_elapsed       | 8          |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0.187      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | -27.7      |
# |    reward             | 0.81348187 |
# |    std                | 1          |
# |    value_loss         | 2.74       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 247       |
# |    iterations         | 500       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.00165  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 618       |
# |    reward             | -13.52603 |
# |    std                | 1         |
# |    value_loss         | 272       |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 247         |
# |    iterations         | 600         |
# |    time_elapsed       | 12          |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0.0167      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | 99.4        |
# |    reward             | -0.15510422 |
# |    std                | 1           |
# |    value_loss         | 6.79        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 247       |
# |    iterations         | 700       |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -68.9     |
# |    reward             | -3.616821 |
# |    std                | 1         |
# |    value_loss         | 4.16      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 248        |
# |    iterations         | 800        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.377     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 38.7       |
# |    reward             | -2.1553257 |
# |    std                | 1          |
# |    value_loss         | 2.05       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 900       |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.259    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 187       |
# |    reward             | -1.292655 |
# |    std                | 1.01      |
# |    value_loss         | 25.2      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 1000      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 44.8      |
# |    reward             | -3.257543 |
# |    std                | 1.01      |
# |    value_loss         | 1.35      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 1100      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0.039     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -221      |
# |    reward             | 1.8817139 |
# |    std                | 1.01      |
# |    value_loss         | 37.3      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 248        |
# |    iterations         | 1200       |
# |    time_elapsed       | 24         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | -0.0121    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -75.2      |
# |    reward             | 0.57279456 |
# |    std                | 1.01       |
# |    value_loss         | 4.67       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 248        |
# |    iterations         | 1300       |
# |    time_elapsed       | 26         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | -38        |
# |    reward             | -2.9435833 |
# |    std                | 1.01       |
# |    value_loss         | 2.75       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 1400      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 96.5      |
# |    reward             | 0.5548517 |
# |    std                | 1.02      |
# |    value_loss         | 8.57      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 1500      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 191       |
# |    reward             | 3.1103804 |
# |    std                | 1.02      |
# |    value_loss         | 28.5      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 249        |
# |    iterations         | 1600       |
# |    time_elapsed       | 32         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | -8.44      |
# |    reward             | 0.78198814 |
# |    std                | 1.02       |
# |    value_loss         | 1.35       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 1700     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -41.7    |
# |    explained_variance | -0.0917  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -21.3    |
# |    reward             | 3.612545 |
# |    std                | 1.02     |
# |    value_loss         | 10.5     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 1800      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | -0.287    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -39.6     |
# |    reward             | 0.7472359 |
# |    std                | 1.02      |
# |    value_loss         | 1         |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 249         |
# |    iterations         | 1900        |
# |    time_elapsed       | 38          |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -41.7       |
# |    explained_variance | -0.216      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1899        |
# |    policy_loss        | 13.6        |
# |    reward             | -0.32282186 |
# |    std                | 1.02        |
# |    value_loss         | 0.532       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 249         |
# |    iterations         | 2000        |
# |    time_elapsed       | 40          |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -41.7       |
# |    explained_variance | -0.106      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | -13.2       |
# |    reward             | -0.83276516 |
# |    std                | 1.02        |
# |    value_loss         | 3.33        |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 249          |
# |    iterations         | 2100         |
# |    time_elapsed       | 42           |
# |    total_timesteps    | 10500        |
# | train/                |              |
# |    entropy_loss       | -41.7        |
# |    explained_variance | -0.162       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2099         |
# |    policy_loss        | 77.7         |
# |    reward             | -0.075898446 |
# |    std                | 1.02         |
# |    value_loss         | 6.11         |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 249        |
# |    iterations         | 2200       |
# |    time_elapsed       | 44         |
# |    total_timesteps    | 11000      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | 0.459      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2199       |
# |    policy_loss        | -3.47      |
# |    reward             | -4.0753603 |
# |    std                | 1.02       |
# |    value_loss         | 0.139      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 249        |
# |    iterations         | 2300       |
# |    time_elapsed       | 46         |
# |    total_timesteps    | 11500      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | -0.0359    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2299       |
# |    policy_loss        | -822       |
# |    reward             | -7.3873096 |
# |    std                | 1.02       |
# |    value_loss         | 475        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 249        |
# |    iterations         | 2400       |
# |    time_elapsed       | 48         |
# |    total_timesteps    | 12000      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2399       |
# |    policy_loss        | 23.5       |
# |    reward             | 0.81102705 |
# |    std                | 1.03       |
# |    value_loss         | 1.35       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 249        |
# |    iterations         | 2500       |
# |    time_elapsed       | 50         |
# |    total_timesteps    | 12500      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2499       |
# |    policy_loss        | -60        |
# |    reward             | -0.5169546 |
# |    std                | 1.03       |
# |    value_loss         | 2.37       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 2600      |
# |    time_elapsed       | 52        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 1.07e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | 23.5      |
# |    reward             | 1.1015445 |
# |    std                | 1.03      |
# |    value_loss         | 0.841     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 249         |
# |    iterations         | 2700        |
# |    time_elapsed       | 54          |
# |    total_timesteps    | 13500       |
# | train/                |             |
# |    entropy_loss       | -41.9       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2699        |
# |    policy_loss        | -44.3       |
# |    reward             | -0.95322883 |
# |    std                | 1.03        |
# |    value_loss         | 2.16        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 2800      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | 370       |
# |    reward             | 1.8537469 |
# |    std                | 1.03      |
# |    value_loss         | 86.9      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 2900      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -113      |
# |    reward             | 1.7608367 |
# |    std                | 1.03      |
# |    value_loss         | 6.62      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 249        |
# |    iterations         | 3000       |
# |    time_elapsed       | 60         |
# |    total_timesteps    | 15000      |
# | train/                |            |
# |    entropy_loss       | -42.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2999       |
# |    policy_loss        | 33.3       |
# |    reward             | -0.6025812 |
# |    std                | 1.03       |
# |    value_loss         | 0.706      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 249         |
# |    iterations         | 3100        |
# |    time_elapsed       | 62          |
# |    total_timesteps    | 15500       |
# | train/                |             |
# |    entropy_loss       | -42.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3099        |
# |    policy_loss        | 88.1        |
# |    reward             | -0.16070484 |
# |    std                | 1.04        |
# |    value_loss         | 4.55        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 249        |
# |    iterations         | 3200       |
# |    time_elapsed       | 64         |
# |    total_timesteps    | 16000      |
# | train/                |            |
# |    entropy_loss       | -42.2      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3199       |
# |    policy_loss        | -14.1      |
# |    reward             | -1.7946329 |
# |    std                | 1.04       |
# |    value_loss         | 5.73       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 249         |
# |    iterations         | 3300        |
# |    time_elapsed       | 66          |
# |    total_timesteps    | 16500       |
# | train/                |             |
# |    entropy_loss       | -42.2       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3299        |
# |    policy_loss        | -320        |
# |    reward             | -0.35783637 |
# |    std                | 1.04        |
# |    value_loss         | 69.5        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 3400      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | 152       |
# |    reward             | 4.2985473 |
# |    std                | 1.04      |
# |    value_loss         | 13.9      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 249         |
# |    iterations         | 3500        |
# |    time_elapsed       | 70          |
# |    total_timesteps    | 17500       |
# | train/                |             |
# |    entropy_loss       | -42.3       |
# |    explained_variance | -0.0707     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3499        |
# |    policy_loss        | 102         |
# |    reward             | 0.118059896 |
# |    std                | 1.04        |
# |    value_loss         | 8.53        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 3600      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -68.9     |
# |    reward             | 1.1568274 |
# |    std                | 1.04      |
# |    value_loss         | 4.27      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 249         |
# |    iterations         | 3700        |
# |    time_elapsed       | 74          |
# |    total_timesteps    | 18500       |
# | train/                |             |
# |    entropy_loss       | -42.2       |
# |    explained_variance | 0.0209      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3699        |
# |    policy_loss        | 118         |
# |    reward             | -0.21912876 |
# |    std                | 1.04        |
# |    value_loss         | 9.13        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 3800      |
# |    time_elapsed       | 76        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | 0.00715   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | 48.4      |
# |    reward             | 1.0697935 |
# |    std                | 1.04      |
# |    value_loss         | 2.62      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 3900      |
# |    time_elapsed       | 77        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -183      |
# |    reward             | 1.0956188 |
# |    std                | 1.04      |
# |    value_loss         | 20.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 4000      |
# |    time_elapsed       | 79        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | -251      |
# |    reward             | 3.0601656 |
# |    std                | 1.04      |
# |    value_loss         | 32.6      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 250         |
# |    iterations         | 4100        |
# |    time_elapsed       | 81          |
# |    total_timesteps    | 20500       |
# | train/                |             |
# |    entropy_loss       | -42.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4099        |
# |    policy_loss        | -17.3       |
# |    reward             | 0.020928549 |
# |    std                | 1.04        |
# |    value_loss         | 1.13        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 249        |
# |    iterations         | 4200       |
# |    time_elapsed       | 84         |
# |    total_timesteps    | 21000      |
# | train/                |            |
# |    entropy_loss       | -42.2      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4199       |
# |    policy_loss        | -51.2      |
# |    reward             | 0.19711863 |
# |    std                | 1.04       |
# |    value_loss         | 2.75       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 4300     |
# |    time_elapsed       | 85       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -42.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -9.05    |
# |    reward             | 4.037478 |
# |    std                | 1.04     |
# |    value_loss         | 1.38     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 4400     |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -42.4    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 107      |
# |    reward             | 3.617622 |
# |    std                | 1.04     |
# |    value_loss         | 14.4     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 4500      |
# |    time_elapsed       | 89        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | 491       |
# |    reward             | 3.002806  |
# |    std                | 1.05      |
# |    value_loss         | 143       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 250        |
# |    iterations         | 4600       |
# |    time_elapsed       | 91         |
# |    total_timesteps    | 23000      |
# | train/                |            |
# |    entropy_loss       | -42.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4599       |
# |    policy_loss        | 198        |
# |    reward             | -1.1125896 |
# |    std                | 1.04       |
# |    value_loss         | 29.1       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 250        |
# |    iterations         | 4700       |
# |    time_elapsed       | 93         |
# |    total_timesteps    | 23500      |
# | train/                |            |
# |    entropy_loss       | -42.4      |
# |    explained_variance | 0.0489     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4699       |
# |    policy_loss        | -127       |
# |    reward             | 0.14688168 |
# |    std                | 1.05       |
# |    value_loss         | 12.5       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 4800      |
# |    time_elapsed       | 95        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -42.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | 24.3      |
# |    reward             | 0.1662921 |
# |    std                | 1.05      |
# |    value_loss         | 0.55      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 250        |
# |    iterations         | 4900       |
# |    time_elapsed       | 97         |
# |    total_timesteps    | 24500      |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | -0.0139    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4899       |
# |    policy_loss        | -31.9      |
# |    reward             | 0.78694934 |
# |    std                | 1.05       |
# |    value_loss         | 3.11       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 250        |
# |    iterations         | 5000       |
# |    time_elapsed       | 99         |
# |    total_timesteps    | 25000      |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4999       |
# |    policy_loss        | -66.3      |
# |    reward             | -0.8779382 |
# |    std                | 1.05       |
# |    value_loss         | 6.46       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 5100      |
# |    time_elapsed       | 101       |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -42.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | -39.9     |
# |    reward             | 0.6899794 |
# |    std                | 1.05      |
# |    value_loss         | 7.51      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 5200     |
# |    time_elapsed       | 103      |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -42.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -225     |
# |    reward             | 6.771379 |
# |    std                | 1.05     |
# |    value_loss         | 43.4     |
# ------------------------------------
# day: 2892, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 5255108.25
# total_reward: 4255108.25
# total_cost: 18041.30
# total_trades: 48276
# Sharpe: 0.935
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 5300      |
# |    time_elapsed       | 105       |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -42.6     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | -36.1     |
# |    reward             | 0.5371551 |
# |    std                | 1.05      |
# |    value_loss         | 0.732     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 250         |
# |    iterations         | 5400        |
# |    time_elapsed       | 107         |
# |    total_timesteps    | 27000       |
# | train/                |             |
# |    entropy_loss       | -42.7       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5399        |
# |    policy_loss        | -53.2       |
# |    reward             | -0.13935764 |
# |    std                | 1.06        |
# |    value_loss         | 3.6         |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 250        |
# |    iterations         | 5500       |
# |    time_elapsed       | 109        |
# |    total_timesteps    | 27500      |
# | train/                |            |
# |    entropy_loss       | -42.7      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5499       |
# |    policy_loss        | -38.6      |
# |    reward             | 0.38222957 |
# |    std                | 1.06       |
# |    value_loss         | 12.3       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 5600      |
# |    time_elapsed       | 111       |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -42.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | -176      |
# |    reward             | 2.2651427 |
# |    std                | 1.06      |
# |    value_loss         | 27.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 5700      |
# |    time_elapsed       | 113       |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -42.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | -588      |
# |    reward             | -7.023079 |
# |    std                | 1.06      |
# |    value_loss         | 225       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 250        |
# |    iterations         | 5800       |
# |    time_elapsed       | 115        |
# |    total_timesteps    | 29000      |
# | train/                |            |
# |    entropy_loss       | -42.8      |
# |    explained_variance | -170       |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5799       |
# |    policy_loss        | 438        |
# |    reward             | 0.31177673 |
# |    std                | 1.06       |
# |    value_loss         | 150        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 250        |
# |    iterations         | 5900       |
# |    time_elapsed       | 117        |
# |    total_timesteps    | 29500      |
# | train/                |            |
# |    entropy_loss       | -42.8      |
# |    explained_variance | -0.0133    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5899       |
# |    policy_loss        | 37.7       |
# |    reward             | -0.7735844 |
# |    std                | 1.06       |
# |    value_loss         | 1.55       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 6000      |
# |    time_elapsed       | 119       |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -42.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5999      |
# |    policy_loss        | 133       |
# |    reward             | -1.412334 |
# |    std                | 1.06      |
# |    value_loss         | 13.7      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 250        |
# |    iterations         | 6100       |
# |    time_elapsed       | 121        |
# |    total_timesteps    | 30500      |
# | train/                |            |
# |    entropy_loss       | -42.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6099       |
# |    policy_loss        | -44.6      |
# |    reward             | -1.8883871 |
# |    std                | 1.06       |
# |    value_loss         | 4.27       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 250        |
# |    iterations         | 6200       |
# |    time_elapsed       | 123        |
# |    total_timesteps    | 31000      |
# | train/                |            |
# |    entropy_loss       | -42.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6199       |
# |    policy_loss        | 1.57       |
# |    reward             | 0.30320302 |
# |    std                | 1.07       |
# |    value_loss         | 0.126      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 6300      |
# |    time_elapsed       | 125       |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -43       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | 366       |
# |    reward             | 6.6683407 |
# |    std                | 1.07      |
# |    value_loss         | 112       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 6400     |
# |    time_elapsed       | 127      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -43      |
# |    explained_variance | -0.039   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 69.6     |
# |    reward             | 1.437934 |
# |    std                | 1.07     |
# |    value_loss         | 2.93     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 250        |
# |    iterations         | 6500       |
# |    time_elapsed       | 129        |
# |    total_timesteps    | 32500      |
# | train/                |            |
# |    entropy_loss       | -43        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6499       |
# |    policy_loss        | 28.3       |
# |    reward             | -4.1072083 |
# |    std                | 1.07       |
# |    value_loss         | 4.13       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 250         |
# |    iterations         | 6600        |
# |    time_elapsed       | 131         |
# |    total_timesteps    | 33000       |
# | train/                |             |
# |    entropy_loss       | -43.1       |
# |    explained_variance | 0.147       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6599        |
# |    policy_loss        | -47         |
# |    reward             | -0.39880335 |
# |    std                | 1.07        |
# |    value_loss         | 4.01        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 250        |
# |    iterations         | 6700       |
# |    time_elapsed       | 133        |
# |    total_timesteps    | 33500      |
# | train/                |            |
# |    entropy_loss       | -43.1      |
# |    explained_variance | -0.132     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6699       |
# |    policy_loss        | -550       |
# |    reward             | -7.0581875 |
# |    std                | 1.07       |
# |    value_loss         | 234        |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 6800     |
# |    time_elapsed       | 135      |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -43.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -237     |
# |    reward             | 0.246197 |
# |    std                | 1.08     |
# |    value_loss         | 31.4     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 250        |
# |    iterations         | 6900       |
# |    time_elapsed       | 137        |
# |    total_timesteps    | 34500      |
# | train/                |            |
# |    entropy_loss       | -43.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6899       |
# |    policy_loss        | -348       |
# |    reward             | -0.6938843 |
# |    std                | 1.08       |
# |    value_loss         | 86.1       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 249        |
# |    iterations         | 7000       |
# |    time_elapsed       | 140        |
# |    total_timesteps    | 35000      |
# | train/                |            |
# |    entropy_loss       | -43.2      |
# |    explained_variance | 0.000529   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6999       |
# |    policy_loss        | 54.5       |
# |    reward             | 0.02107155 |
# |    std                | 1.08       |
# |    value_loss         | 2.18       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 7100      |
# |    time_elapsed       | 141       |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -43.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | 2.83      |
# |    reward             | 0.6510213 |
# |    std                | 1.08      |
# |    value_loss         | 0.229     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 7200     |
# |    time_elapsed       | 143      |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -43.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | -317     |
# |    reward             | 1.209581 |
# |    std                | 1.08     |
# |    value_loss         | 50.2     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 250        |
# |    iterations         | 7300       |
# |    time_elapsed       | 145        |
# |    total_timesteps    | 36500      |
# | train/                |            |
# |    entropy_loss       | -43.3      |
# |    explained_variance | -9.2e-05   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7299       |
# |    policy_loss        | 264        |
# |    reward             | 0.44578466 |
# |    std                | 1.08       |
# |    value_loss         | 58.2       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 250        |
# |    iterations         | 7400       |
# |    time_elapsed       | 147        |
# |    total_timesteps    | 37000      |
# | train/                |            |
# |    entropy_loss       | -43.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7399       |
# |    policy_loss        | -248       |
# |    reward             | -3.8194895 |
# |    std                | 1.08       |
# |    value_loss         | 37.3       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 250        |
# |    iterations         | 7500       |
# |    time_elapsed       | 149        |
# |    total_timesteps    | 37500      |
# | train/                |            |
# |    entropy_loss       | -43.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7499       |
# |    policy_loss        | 208        |
# |    reward             | -0.7128125 |
# |    std                | 1.09       |
# |    value_loss         | 27.1       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 7600      |
# |    time_elapsed       | 151       |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -43.5     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7599      |
# |    policy_loss        | -162      |
# |    reward             | 2.3427176 |
# |    std                | 1.09      |
# |    value_loss         | 14.1      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 7700     |
# |    time_elapsed       | 153      |
# |    total_timesteps    | 38500    |
# | train/                |          |
# |    entropy_loss       | -43.5    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7699     |
# |    policy_loss        | -126     |
# |    reward             | 1.4115   |
# |    std                | 1.09     |
# |    value_loss         | 8.2      |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 250        |
# |    iterations         | 7800       |
# |    time_elapsed       | 155        |
# |    total_timesteps    | 39000      |
# | train/                |            |
# |    entropy_loss       | -43.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7799       |
# |    policy_loss        | -22.1      |
# |    reward             | -3.4579096 |
# |    std                | 1.09       |
# |    value_loss         | 2.27       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 7900      |
# |    time_elapsed       | 157       |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -43.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7899      |
# |    policy_loss        | 329       |
# |    reward             | 2.5634198 |
# |    std                | 1.09      |
# |    value_loss         | 70.3      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 8000      |
# |    time_elapsed       | 159       |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -43.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7999      |
# |    policy_loss        | -8.46     |
# |    reward             | 2.8080993 |
# |    std                | 1.09      |
# |    value_loss         | 1.48      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 8100      |
# |    time_elapsed       | 161       |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -43.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8099      |
# |    policy_loss        | 37.4      |
# |    reward             | 3.3200688 |
# |    std                | 1.09      |
# |    value_loss         | 11.4      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 250        |
# |    iterations         | 8200       |
# |    time_elapsed       | 163        |
# |    total_timesteps    | 41000      |
# | train/                |            |
# |    entropy_loss       | -43.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8199       |
# |    policy_loss        | 41.8       |
# |    reward             | 0.12585863 |
# |    std                | 1.09       |
# |    value_loss         | 1.42       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 250        |
# |    iterations         | 8300       |
# |    time_elapsed       | 165        |
# |    total_timesteps    | 41500      |
# | train/                |            |
# |    entropy_loss       | -43.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8299       |
# |    policy_loss        | -74        |
# |    reward             | -1.5253294 |
# |    std                | 1.1        |
# |    value_loss         | 3.16       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 8400      |
# |    time_elapsed       | 167       |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -43.7     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8399      |
# |    policy_loss        | 41        |
# |    reward             | -2.288078 |
# |    std                | 1.09      |
# |    value_loss         | 1.71      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 250         |
# |    iterations         | 8500        |
# |    time_elapsed       | 169         |
# |    total_timesteps    | 42500       |
# | train/                |             |
# |    entropy_loss       | -43.7       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8499        |
# |    policy_loss        | -122        |
# |    reward             | -0.63955355 |
# |    std                | 1.1         |
# |    value_loss         | 8.84        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 61         |
# |    iterations         | 8600       |
# |    time_elapsed       | 704        |
# |    total_timesteps    | 43000      |
# | train/                |            |
# |    entropy_loss       | -43.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8599       |
# |    policy_loss        | 1.48       |
# |    reward             | -6.3069205 |
# |    std                | 1.1        |
# |    value_loss         | 17.4       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 61          |
# |    iterations         | 8700        |
# |    time_elapsed       | 706         |
# |    total_timesteps    | 43500       |
# | train/                |             |
# |    entropy_loss       | -43.7       |
# |    explained_variance | 0.0665      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8699        |
# |    policy_loss        | -12.6       |
# |    reward             | 0.008492338 |
# |    std                | 1.1         |
# |    value_loss         | 0.606       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 62         |
# |    iterations         | 8800       |
# |    time_elapsed       | 708        |
# |    total_timesteps    | 44000      |
# | train/                |            |
# |    entropy_loss       | -43.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8799       |
# |    policy_loss        | -48.6      |
# |    reward             | 0.67147213 |
# |    std                | 1.1        |
# |    value_loss         | 1.43       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 62        |
# |    iterations         | 8900      |
# |    time_elapsed       | 710       |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -43.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8899      |
# |    policy_loss        | -19       |
# |    reward             | 1.2285994 |
# |    std                | 1.1       |
# |    value_loss         | 1.53      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 63          |
# |    iterations         | 9000        |
# |    time_elapsed       | 712         |
# |    total_timesteps    | 45000       |
# | train/                |             |
# |    entropy_loss       | -43.8       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8999        |
# |    policy_loss        | 22.9        |
# |    reward             | -0.60999584 |
# |    std                | 1.1         |
# |    value_loss         | 1.55        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 63        |
# |    iterations         | 9100      |
# |    time_elapsed       | 714       |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -43.8     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9099      |
# |    policy_loss        | -6.4      |
# |    reward             | 2.2908018 |
# |    std                | 1.1       |
# |    value_loss         | 0.623     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 64       |
# |    iterations         | 9200     |
# |    time_elapsed       | 716      |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -43.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9199     |
# |    policy_loss        | 33.9     |
# |    reward             | 4.287951 |
# |    std                | 1.1      |
# |    value_loss         | 3.48     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 64         |
# |    iterations         | 9300       |
# |    time_elapsed       | 718        |
# |    total_timesteps    | 46500      |
# | train/                |            |
# |    entropy_loss       | -43.8      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9299       |
# |    policy_loss        | -93.5      |
# |    reward             | 0.56776154 |
# |    std                | 1.1        |
# |    value_loss         | 5.7        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 65        |
# |    iterations         | 9400      |
# |    time_elapsed       | 720       |
# |    total_timesteps    | 47000     |
# | train/                |           |
# |    entropy_loss       | -43.9     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9399      |
# |    policy_loss        | 114       |
# |    reward             | -0.679731 |
# |    std                | 1.1       |
# |    value_loss         | 7.26      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 65          |
# |    iterations         | 9500        |
# |    time_elapsed       | 722         |
# |    total_timesteps    | 47500       |
# | train/                |             |
# |    entropy_loss       | -43.9       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9499        |
# |    policy_loss        | 75.5        |
# |    reward             | -0.17132935 |
# |    std                | 1.1         |
# |    value_loss         | 6.08        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 66         |
# |    iterations         | 9600       |
# |    time_elapsed       | 724        |
# |    total_timesteps    | 48000      |
# | train/                |            |
# |    entropy_loss       | -43.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9599       |
# |    policy_loss        | -321       |
# |    reward             | 0.13448374 |
# |    std                | 1.1        |
# |    value_loss         | 53.9       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 66         |
# |    iterations         | 9700       |
# |    time_elapsed       | 726        |
# |    total_timesteps    | 48500      |
# | train/                |            |
# |    entropy_loss       | -43.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9699       |
# |    policy_loss        | 57.5       |
# |    reward             | -1.0580473 |
# |    std                | 1.1        |
# |    value_loss         | 2.39       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 67        |
# |    iterations         | 9800      |
# |    time_elapsed       | 728       |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -43.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9799      |
# |    policy_loss        | 144       |
# |    reward             | 3.6270463 |
# |    std                | 1.1       |
# |    value_loss         | 16.9      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 67          |
# |    iterations         | 9900        |
# |    time_elapsed       | 730         |
# |    total_timesteps    | 49500       |
# | train/                |             |
# |    entropy_loss       | -43.9       |
# |    explained_variance | -4.77e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9899        |
# |    policy_loss        | -4.21       |
# |    reward             | -0.05840838 |
# |    std                | 1.1         |
# |    value_loss         | 0.0601      |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 68        |
# |    iterations         | 10000     |
# |    time_elapsed       | 732       |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -43.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9999      |
# |    policy_loss        | 23.2      |
# |    reward             | -0.900833 |
# |    std                | 1.1       |
# |    value_loss         | 0.647     |
# -------------------------------------

# %% [markdown]
# ### Model 2: DDPG

# %%
agent = DRLAgent(env = env_train)
model_ddpg = agent.get_model("ddpg")
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000)
# Out:
# day: 2892, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 5275602.43
# total_reward: 4275602.43
# total_cost: 5627.13
# total_trades: 36256
# Sharpe: 0.946
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 140       |
# |    time_elapsed    | 82        |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | -26.8     |
# |    critic_loss     | 135       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8679      |
# |    reward          | 10.533023 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 129       |
# |    time_elapsed    | 178       |
# |    total_timesteps | 23144     |
# | train/             |           |
# |    actor_loss      | -18.3     |
# |    critic_loss     | 14.7      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20251     |
# |    reward          | 10.533023 |
# ----------------------------------
# day: 2892, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 7302334.31
# total_reward: 6302334.31
# total_cost: 999.00
# total_trades: 28857
# Sharpe: 0.988
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 125       |
# |    time_elapsed    | 275       |
# |    total_timesteps | 34716     |
# | train/             |           |
# |    actor_loss      | -18.1     |
# |    critic_loss     | 9.16      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31823     |
# |    reward          | 10.533023 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 124       |
# |    time_elapsed    | 371       |
# |    total_timesteps | 46288     |
# | train/             |           |
# |    actor_loss      | -18.9     |
# |    critic_loss     | 7.41      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 43395     |
# |    reward          | 10.533023 |
# ----------------------------------

# %% [markdown]
# ### Model 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=50000)

# %% [markdown]
# ### Model 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=30000)

# %% [markdown]
# ### Model 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 1000000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=60000)
# Out:
# day: 2892, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 3750425.08
# total_reward: 2750425.08
# total_cost: 129986.08
# total_trades: 47122
# Sharpe: 0.729
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 101       |
# |    time_elapsed    | 114       |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | 424       |
# |    critic_loss     | 63.4      |
# |    ent_coef        | 0.152     |
# |    ent_coef_loss   | -91.1     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 11471     |
# |    reward          | 1.8715892 |
# ----------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 101      |
# |    time_elapsed    | 227      |
# |    total_timesteps | 23144    |
# | train/             |          |
# |    actor_loss      | 111      |
# |    critic_loss     | 83.1     |
# |    ent_coef        | 0.0481   |
# |    ent_coef_loss   | -133     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23043    |
# |    reward          | 8.448614 |
# ---------------------------------
# day: 2892, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 5828442.22
# total_reward: 4828442.22
# total_cost: 4774.99
# total_trades: 45391
# Sharpe: 0.839
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 101       |
# |    time_elapsed    | 341       |
# |    total_timesteps | 34716     |
# | train/             |           |
# |    actor_loss      | 13.5      |
# |    critic_loss     | 18        |
# |    ent_coef        | 0.0155    |
# |    ent_coef_loss   | -140      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 34615     |
# |    reward          | 6.5816336 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 101       |
# |    time_elapsed    | 454       |
# |    total_timesteps | 46288     |
# | train/             |           |
# |    actor_loss      | 7.79      |
# |    critic_loss     | 10.6      |
# |    ent_coef        | 0.00524   |
# |    ent_coef_loss   | -74.7     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 46187     |
# |    reward          | 2.5967147 |
# ----------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 101      |
# |    time_elapsed    | 567      |
# |    total_timesteps | 57860    |
# | train/             |          |
# |    actor_loss      | 3.38     |
# |    critic_loss     | 7.81     |
# |    ent_coef        | 0.00281  |
# |    ent_coef_loss   | -1.62    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 57759    |
# |    reward          | 2.843999 |
# ---------------------------------

# %% [markdown]
# ## Trading
# Assume that we have $1,000,000 initial capital at 2020-07-01. We use the DDPG model to trade Dow jones 30 stocks.

# %% [markdown]
# ### Set turbulence threshold
# Set the turbulence threshold to be greater than the maximum of insample turbulence data, if current turbulence index is greater than the threshold, then we assume that the current market is volatile

# %%
data_risk_indicator = processed_full[(processed_full.date<'2020-07-01') & (processed_full.date>='2009-01-01')]
insample_risk_indicator = data_risk_indicator.drop_duplicates(subset=['date'])

# %%
insample_risk_indicator.vix.describe()
# Out:
# count    2893.000000
# mean       18.824245
# std         8.489311
# min         9.140000
# 25%        13.330000
# 50%        16.139999
# 75%        21.309999
# max        82.690002
# Name: vix, dtype: float64

# %%
insample_risk_indicator.vix.quantile(0.996)
# Out:
# 57.40400183105453

# %%
insample_risk_indicator.turbulence.describe()
# Out:
# count    2893.000000
# mean       34.574232
# std        43.787144
# min         0.000000
# 25%        14.966415
# 50%        24.124362
# 75%        39.161957
# max       652.503824
# Name: turbulence, dtype: float64

# %%
insample_risk_indicator.turbulence.quantile(0.996)
# Out:
# 276.4516803931362

# %% [markdown]
# ### Trade
#
# DRL model needs to update periodically in order to take full advantage of the data, ideally we need to retrain our model yearly, quarterly, or monthly. We also need to tune the parameters along the way, in this notebook I only use the in-sample data from 2009-01 to 2020-07 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
#trade = data_split(processed_full, '2020-07-01','2021-10-31')
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
trade.head()
# Out:
#          date   tic        open        high         low       close  \
# 0  2020-07-01  AAPL   91.279999   91.839996   90.977501   89.904594
# 0  2020-07-01  AMGN  235.520004  256.230011  232.580002  240.153946
# 0  2020-07-01   AXP   95.250000   96.959999   93.639999   92.086380
# 0  2020-07-01    BA  185.880005  190.610001  180.039993  180.320007
# 0  2020-07-01   CAT  129.380005  129.399994  125.879997  120.651634
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  110737200.0  2.0  3.014603   92.699319   80.179953  62.807126  107.491819
# 0    6575800.0  2.0  3.636393  232.397421  200.212949  61.279630  271.386075
# 0    3301000.0  2.0 -0.389162  110.423945   87.759332  48.504818  -66.328697
# 0   49036700.0  2.0  5.443193  220.721139  160.932863  50.925771   24.220608
# 0    2807800.0  2.0  1.272630  130.624272  113.353134  52.865421   35.597292
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  29.730532     83.933767     77.717544  28.620001   53.068143
# 0  46.806139    214.858661    215.931664  28.620001   53.068143
# 0   3.142448     97.244636     90.695525  28.620001   53.068143
# 0  15.932920    176.472335    155.614168  28.620001   53.068143
# 0  14.457404    119.412837    113.646674  28.620001   53.068143

# %%
df_account_value, df_actions = DRLAgent.DRL_prediction(
    model=trained_sac, 
    environment = e_trade_gym)
# Out:
# hit end!

# %%
df_account_value.shape
# Out:
# (336, 2)

# %%
df_account_value.tail()
# Out:
#            date  account_value
# 331  2021-10-22   1.450417e+06
# 332  2021-10-25   1.456955e+06
# 333  2021-10-26   1.457912e+06
# 334  2021-10-27   1.438427e+06
# 335  2021-10-28   1.448063e+06

# %%
df_actions.head()
# Out:
#             AAPL  AMGN  AXP  BA  CAT  CRM  CSCO  CVX  DIS  GS  ...  MRK  MSFT  \
# date                                                           ...
# 2020-07-01    96     0    0  92   91   96    93    0   79  97  ...    0     0
# 2020-07-02    96     0    0  92   91   96    93    0   79  97  ...    0     0
# 2020-07-06    96     0    0  92   91   96    93    0   79  97  ...    0     0
# 2020-07-07    96     0    0  92   91   96    93    0   79  97  ...    0     0
# 2020-07-08    96     0    0  92   91   96    93    0   79  97  ...    0     0
#
#             NKE  PG  TRV  UNH   V  VZ  WBA  WMT
# date
# 2020-07-01    0  97    0    0  97  89    0    0
# 2020-07-02    0  97    0    0  97  89    0    0
# 2020-07-06    0  97    0    0  97  89    0    0
# 2020-07-07    0  97    0    0  97  89    0    0
# 2020-07-08    0  97    0    0  97  89    0    0
#
# [5 rows x 29 columns]

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
perf_stats_all.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return          0.320051
# Cumulative returns     0.448063
# Annual volatility      0.155290
# Sharpe ratio           1.871866
# Calmar ratio           3.111252
# Stability              0.916583
# Max drawdown          -0.102869
# Omega ratio            1.377465
# Sortino ratio          2.803189
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.136893
# Daily value at risk   -0.018411
# dtype: float64
# /Users/yudongtan/miniforge3/lib/python3.9/site-packages/pyfolio/timeseries.py:724: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (336, 8)
# Annual return          0.269722
# Cumulative returns     0.374922
# Annual volatility      0.139083
# Sharpe ratio           1.792302
# Calmar ratio           3.020136
# Stability              0.919220
# Max drawdown          -0.089308
# Omega ratio            1.347571
# Sortino ratio          2.655481
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.052781
# Daily value at risk   -0.016534
# dtype: float64
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# /Users/yudongtan/miniforge3/lib/python3.9/site-packages/pyfolio/timeseries.py:724: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()

# %%
df_account_value.loc[0,'date']
# Out:
# '2020-07-01'

# %%
df_account_value.loc[len(df_account_value)-1,'date']
# Out:
# '2021-10-28'

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
import pyfolio
import importlib
importlib.reload(pyfolio)
import finrl
importlib.reload(finrl)
importlib.reload(finrl.plot)
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
             baseline_ticker = '^DJI', 
             baseline_start = df_account_value.loc[0,'date'],
             baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (336, 8)
# /Users/yudongtan/projects/FinRL/finrl/finrl_meta/preprocessor/yahoodownloader.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# /Users/yudongtan/miniforge3/lib/python3.9/site-packages/seaborn/rcmod.py:400: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) >= "3.0":
# /Users/yudongtan/miniforge3/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /Users/yudongtan/miniforge3/lib/python3.9/site-packages/pyfolio/timeseries.py:724: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-07-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-28</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>16</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>32.0%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>44.8%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>15.5%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.87</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>3.11</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-10.3%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.38</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>2.80</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.14</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.8%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.03</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>1.05</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [62], in <cell line: 15>()
#      11 from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
#      12 # S&P 500: ^GSPC
#      13 # Dow Jones Index: ^DJI
#      14 # NASDAQ 100: ^NDX
# ---> 15 backtest_plot(df_account_value,
#      16              baseline_ticker = '^DJI',
#      17              baseline_start = df_account_value.loc[0,'date'],
#      18              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
#
# File ~/projects/FinRL/finrl/plot.py:65, in backtest_plot(account_value, baseline_start, baseline_end, baseline_ticker, value_col_name)
#      62 baseline_returns = get_daily_return(baseline_df, value_col_name="close")
#      64 with pyfolio.plotting.plotting_context(font_scale=1.1):
# ---> 65     pyfolio.create_full_tear_sheet(
#      66         returns=test_returns, benchmark_rets=baseline_returns, set_context=False
#      67     )
#
# File ~/miniforge3/lib/python3.9/site-packages/pyfolio/tears.py:201, in create_full_tear_sheet(returns, positions, transactions, market_data, benchmark_rets, slippage, live_start_date, sector_mappings, bayesian, round_trips, estimate_intraday, hide_positions, cone_std, bootstrap, unadjusted_returns, style_factor_panel, sectors, caps, shares_held, volumes, percentile, turnover_denom, set_context, factor_returns, factor_loadings, pos_in_dollars, header_rows, factor_partitions)
#     195     returns = txn.adjust_returns_for_slippage(returns, positions,
#     196                                               transactions, slippage)
#     198 positions = utils.check_intraday(estimate_intraday, returns,
#     199                                  positions, transactions)
# --> 201 create_returns_tear_sheet(
#     202     returns,
#     203     positions=positions,
#     204     transactions=transactions,
#     205     live_start_date=live_start_date,
#     206     cone_std=cone_std,
#     207     benchmark_rets=benchmark_rets,
#     208     bootstrap=bootstrap,
#     209     turnover_denom=turnover_denom,
#     210     header_rows=header_rows,
#     211     set_context=set_context)
#     213 create_interesting_times_tear_sheet(returns,
#     214                                     benchmark_rets=benchmark_rets,
#     215                                     set_context=set_context)
#     217 if positions is not None:
#
# File ~/miniforge3/lib/python3.9/site-packages/pyfolio/plotting.py:54, in customize.<locals>.call_w_context(*args, **kwargs)
#      52         return func(*args, **kwargs)
#      53 else:
# ---> 54     return func(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.9/site-packages/pyfolio/tears.py:504, in create_returns_tear_sheet(returns, positions, transactions, live_start_date, cone_std, benchmark_rets, bootstrap, turnover_denom, header_rows, return_fig)
#     494     returns = utils.clip_returns_to_benchmark(returns, benchmark_rets)
#     496 plotting.show_perf_stats(returns, benchmark_rets,
#     497                          positions=positions,
#     498                          transactions=transactions,
#    (...)
#     501                          live_start_date=live_start_date,
#     502                          header_rows=header_rows)
# --> 504 plotting.show_worst_drawdown_periods(returns)
#     506 vertical_sections = 11
#     508 if live_start_date is not None:
#
# File ~/miniforge3/lib/python3.9/site-packages/pyfolio/plotting.py:1664, in show_worst_drawdown_periods(returns, top)
#    1648 def show_worst_drawdown_periods(returns, top=5):
#    1649     """
#    1650     Prints information about the worst drawdown periods.
#    1651
#    (...)
#    1661         Amount of top drawdowns periods to plot (default 5).
#    1662     """
# -> 1664     drawdown_df = timeseries.gen_drawdown_table(returns, top=top)
#    1665     utils.print_table(
#    1666         drawdown_df.sort_values('Net drawdown in %', ascending=False),
#    1667         name='Worst drawdown periods',
#    1668         float_format='{0:.2f}'.format,
#    1669     )
#
# File ~/miniforge3/lib/python3.9/site-packages/pyfolio/timeseries.py:1008, in gen_drawdown_table(returns, top)
#    1003     df_drawdowns.loc[i, 'Duration'] = len(pd.date_range(peak,
#    1004                                                         recovery,
#    1005                                                         freq='B'))
#    1006 df_drawdowns.loc[i, 'Peak date'] = (peak.to_pydatetime()
#    1007                                     .strftime('%Y-%m-%d'))
# -> 1008 df_drawdowns.loc[i, 'Valley date'] = (valley.to_pydatetime()
#    1009                                       .strftime('%Y-%m-%d'))
#    1010 if isinstance(recovery, float):
#    1011     df_drawdowns.loc[i, 'Recovery date'] = recovery
#
# AttributeError: 'numpy.int64' object has no attribute 'to_pydatetime'
